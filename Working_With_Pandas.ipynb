# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivas123565/Python-basics-mini-project-1/blob/main/Working_With_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
datasatPath ='/retail_transactions.csv'
df = pd.read_csv(datasatPath)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])

# %%
retail_df = df

# %%
print("First 15 rows of the DataFrame:")
print(retail_df.head(15))
# Out:
# First 15 rows of the DataFrame:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# 6           T007      2024-01-07      103        1983        586
# 7           T008      2024-01-08      101        1806        569
# 8           T009      2024-01-09      101        1925        548
# 9           T010      2024-01-10      101        1711        565
# 10          T011      2024-01-11      103        1276        565
# 11          T012      2024-01-12      101        1486        523
# 12          T013      2024-01-13      103        1597        516
# ...

# %%
print("\nDataFrame Info:")
print(retail_df.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    object
#  1   TransactionDate  100 non-null    datetime64[ns]
#  2   StoreID          100 non-null    int64
#  3   CustomerID       100 non-null    int64
#  4   ProductID        100 non-null    int64
#  5   ProductCategory  100 non-null    object
#  6   Quantity         100 non-null    int64
#  7   Price            100 non-null    int64
#  8   PaymentType      100 non-null    object
#  9   Discount         75 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 7.9+ KB
# None

# %%
print("\nDataFrame Description:")
print(retail_df.describe())
# Out:
# DataFrame Description:
#            TransactionDate     StoreID   CustomerID   ProductID    Quantity  \
# count                  100  100.000000   100.000000  100.000000  100.000000
# mean   2024-02-19 12:00:00  102.730000  1552.520000  554.390000    5.370000
# min    2024-01-01 00:00:00  101.000000  1013.000000  501.000000    1.000000
# 25%    2024-01-25 18:00:00  101.000000  1310.250000  529.750000    3.000000
# 50%    2024-02-19 12:00:00  103.000000  1534.000000  554.000000    5.500000
# 75%    2024-03-15 06:00:00  104.000000  1800.750000  579.500000    8.000000
# max    2024-04-09 00:00:00  105.000000  1983.000000  600.000000   10.000000
# std                    NaN    1.384291   268.295461   28.544098    3.013957
#
#            Price   Discount
# count  100.00000  75.000000
# mean   282.15000   7.733333
# min     50.00000   0.000000
# 25%    165.75000   2.500000
# 50%    280.00000  10.000000
# 75%    415.25000  12.500000
# max    500.00000  15.000000
# ...

# %%
print("\nMissing values per column:")
print(retail_df.isnull().sum())
# Out:
# Missing values per column:
# TransactionID       0
# TransactionDate     0
# StoreID             0
# CustomerID          0
# ProductID           0
# ProductCategory     0
# Quantity            0
# Price               0
# PaymentType         0
# Discount           25
# dtype: int64

# %%
retail_df['Discount'] = retail_df['Discount'].fillna(0)

# %%
print("\nMissing values after filling Discount:")
print(retail_df['Discount'].isnull().sum())
# Out:
# Missing values after filling Discount:
# 25

# %%
retail_df['NetPrice'] = retail_df['Price'] * (1 - retail_df['Discount'] / 100)

# %%
retail_df['TotalSale'] = retail_df['Quantity'] * retail_df['NetPrice']

# %%
print("\nDataFrame with new NetPrice and TotalSale columns:")
print(retail_df.head())
# Out:
# DataFrame with new NetPrice and TotalSale columns:
#   TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0          T001      2024-01-01      102        1646        545
# 1          T002      2024-01-02      103        1226        542
# 2          T003      2024-01-03      102        1515        593
# 3          T004      2024-01-04      103        1793        560
# 4          T005      2024-01-05      105        1864        523
#
#   ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0     Electronics         1    150      Credit      15.0     127.5      127.5
# 1            Toys         2    317       Debit      10.0     285.3      570.6
# 2     Electronics         5    165       Debit       0.0     165.0      825.0
# 3       Furniture         6    496       Debit      10.0     446.4     2678.4
# 4         Grocery        10    166       Debit       0.0     166.0     1660.0

# %%
filtered_df = retail_df[retail_df['TotalSale'] >= 20].copy()

# %%
filtered_df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# ...

# %%
print("\nShape of the filtered DataFrame:")
print(filtered_df.shape)
# Out:
# Shape of the filtered DataFrame:
# (100, 12)

# %%
filtered_df['PaymentType'] = filtered_df['PaymentType'].astype('category')

# %%
print("\nData types after converting PaymentType to category:")
print(filtered_df.dtypes)
# Out:
# Data types after converting PaymentType to category:
# TransactionID              object
# TransactionDate    datetime64[ns]
# StoreID                     int64
# CustomerID                  int64
# ProductID                   int64
# ProductCategory            object
# Quantity                    int64
# Price                       int64
# PaymentType              category
# Discount                  float64
# NetPrice                  float64
# TotalSale                 float64
# dtype: object

# %%
grouped = filtered_df.groupby('ProductCategory').agg(
    TotalQuantity=('Quantity', 'sum'),
    TotalSale=('TotalSale', 'sum')
)

# %%
filtered_df.groupby
# Out:
# <bound method DataFrame.groupby of    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# ...

# %%
grouped_sorted = grouped.sort_values(by='TotalSale', ascending=False)

# %%
grouped_sorted
# Out:
#                  TotalQuantity  TotalSale
# ProductCategory
# Toys                       137   44326.35
# Furniture                  130   39655.55
# Apparel                    117   28055.35
# Grocery                     75   17585.80
# Electronics                 78   15980.65

# %%
print("\nGrouped and sorted by TotalSale:")
print(grouped_sorted)
# Out:
# Grouped and sorted by TotalSale:
#                  TotalQuantity  TotalSale
# ProductCategory
# Toys                       137   44326.35
# Furniture                  130   39655.55
# Apparel                    117   28055.35
# Grocery                     75   17585.80
# Electronics                 78   15980.65

# %%
top_3_categories = grouped_sorted.head(3)
print("\nTop 3 product categories with the highest total sales:")
print(top_3_categories)
# Out:
# Top 3 product categories with the highest total sales:
#                  TotalQuantity  TotalSale
# ProductCategory
# Toys                       137   44326.35
# Furniture                  130   39655.55
# Apparel                    117   28055.35

# %%
multi_grouped = filtered_df.groupby(['StoreID', 'ProductCategory'])['TotalSale'].mean().reset_index()

# %%
multi_grouped
# Out:
#     StoreID ProductCategory    TotalSale
# 0       101         Apparel  1344.550000
# 1       101     Electronics  1128.916667
# 2       101       Furniture  1317.943750
# 3       101            Toys  2227.016667
# 4       102         Apparel  1452.180000
# 5       102     Electronics   591.380000
# 6       102       Furniture  2565.900000
# 7       102         Grocery   171.900000
# 8       102            Toys  1036.557143
# 9       103         Apparel  1021.950000
# 10      103     Electronics   817.666667
# 11      103       Furniture  1560.771429
# 12      103         Grocery   954.850000
# 13      103            Toys  1239.180000
# 14      104         Apparel   722.000000
# 15      104     Electronics   852.333333
# 16      104       Furniture  1528.928571
# 17      104         Grocery  1118.833333
# 18      104            Toys  1367.700000
# 19      105         Apparel  2398.450000
# 20      105     Electronics  2313.500000
# 21      105       Furniture  1176.150000
# ...

# %%
multi_grouped = multi_grouped.rename(columns={'TotalSale': 'AvgTotalSale'})

# %%
print("\nMulti-level grouping by StoreID and ProductCategory with average TotalSale:")
print(multi_grouped)
# Out:
# Multi-level grouping by StoreID and ProductCategory with average TotalSale:
#     StoreID ProductCategory  AvgTotalSale
# 0       101         Apparel   1344.550000
# 1       101     Electronics   1128.916667
# 2       101       Furniture   1317.943750
# 3       101            Toys   2227.016667
# 4       102         Apparel   1452.180000
# 5       102     Electronics    591.380000
# 6       102       Furniture   2565.900000
# 7       102         Grocery    171.900000
# 8       102            Toys   1036.557143
# 9       103         Apparel   1021.950000
# 10      103     Electronics    817.666667
# 11      103       Furniture   1560.771429
# 12      103         Grocery    954.850000
# 13      103            Toys   1239.180000
# 14      104         Apparel    722.000000
# 15      104     Electronics    852.333333
# 16      104       Furniture   1528.928571
# 17      104         Grocery   1118.833333
# 18      104            Toys   1367.700000
# ...

# %%
multi_grouped = filtered_df.groupby(['StoreID', 'ProductCategory'])['TotalSale'].mean().reset_index()
multi_grouped = multi_grouped.rename(columns={'TotalSale': 'AvgTotalSale'})
sorted_grouped = multi_grouped.sort_values(['StoreID','AvgTotalSale'], ascending=[True, False])

# %%
sorted_grouped
# Out:
#     StoreID ProductCategory  AvgTotalSale
# 3       101            Toys   2227.016667
# 0       101         Apparel   1344.550000
# 2       101       Furniture   1317.943750
# 1       101     Electronics   1128.916667
# 6       102       Furniture   2565.900000
# 4       102         Apparel   1452.180000
# 8       102            Toys   1036.557143
# 5       102     Electronics    591.380000
# 7       102         Grocery    171.900000
# 11      103       Furniture   1560.771429
# 13      103            Toys   1239.180000
# 9       103         Apparel   1021.950000
# 12      103         Grocery    954.850000
# 10      103     Electronics    817.666667
# 16      104       Furniture   1528.928571
# 18      104            Toys   1367.700000
# 17      104         Grocery   1118.833333
# 15      104     Electronics    852.333333
# 14      104         Apparel    722.000000
# 23      105            Toys   4048.000000
# 19      105         Apparel   2398.450000
# ...

# %%
top_categories_per_store = sorted_grouped.groupby('StoreID').first().reset_index()

# %%
summary_df = top_categories_per_store[['StoreID', 'ProductCategory', 'AvgTotalSale']]

# %%
summary_df
# Out:
#    StoreID ProductCategory  AvgTotalSale
# 0      101            Toys   2227.016667
# 1      102       Furniture   2565.900000
# 2      103       Furniture   1560.771429
# 3      104       Furniture   1528.928571
# 4      105            Toys   4048.000000

# %%
print("\nSummary DataFrame with top ProductCategory and average TotalSale for each store:")
print(summary_df)
# Out:
# Summary DataFrame with top ProductCategory and average TotalSale for each store:
#    StoreID ProductCategory  AvgTotalSale
# 0      101            Toys   2227.016667
# 1      102       Furniture   2565.900000
# 2      103       Furniture   1560.771429
# 3      104       Furniture   1528.928571
# 4      105            Toys   4048.000000

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(grouped_sorted.index, grouped_sorted['TotalSale'], color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.title('Total Sales per Product Category')
plt.show()

# %%
plt.scatter(filtered_df['Quantity'], filtered_df['NetPrice'], color='coral', alpha=0.5)
plt.xlabel('Quantity')
plt.ylabel('Net Price')
plt.title('Quantity vs Net Price')
plt.show()

# %%
plt.plot(grouped.index, grouped['TotalQuantity'], marker='o', linestyle='-', color='green')
plt.xlabel('Product Category')
plt.ylabel('Total Quantity Sold')
plt.title('Total Quantity Sold by Product Category')
plt.show()

# %%
df['Revenue'] = df['Quantity'] * df['Price'] * (1 - df['Discount'] / 100)
total_revenue = df['Revenue'].sum()
print(f"Total Revenue: {total_revenue:.2f}")
# Out:
# Total Revenue: 145603.70

# %%
most_frequently_product = df['ProductID'].value_counts().idxmax()
print(f"most frequently purchased product is: {most_frequently_product}")
# Out:
# most frequently purchased product is: 523

# %%
average_transaction_amount = df['Revenue'].mean()
print(f"Average Transaction Amount: {average_transaction_amount:.2f}")
# Out:
# Average Transaction Amount: 1456.04

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Transaction_ID': [101, 102, 103, 104, 105],
    'Total_Amount': [45000, 75000, 30000, 120000, 55000]
}

df = pd.DataFrame(data)

# Filtering transactions where Total_Amount > 50000
filtered_df = df[df['Total_Amount'] > 50000]

print(filtered_df)
# Out:
#    Transaction_ID  Total_Amount
# 1             102         75000
# 3             104        120000
# 4             105         55000

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Customer_ID': ['C001', 'C002', 'C003', 'C001', 'C002', 'C004', 'C003'],
    'Total_Amount': [40000, 75000, 30000, 60000, 50000, 90000, 70000]
}

df = pd.DataFrame(data)

# Group by 'Customer_ID' and sum the 'Total_Amount'
customer_spending = df.groupby('Customer_ID')['Total_Amount'].sum()

# Sort in descending order and get the top 3 customers
top_customers = customer_spending.sort_values(ascending=False).head(3)

print(top_customers)
# Out:
# Customer_ID
# C002    125000
# C001    100000
# C003    100000
# Name: Total_Amount, dtype: int64
